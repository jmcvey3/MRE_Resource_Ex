# %%
import xarray as xr

ds = xr.open_dataset(
    "../../storage/root/data/buoy.waves.b1/buoy.waves.b1.20210819.210649.nc"
)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 3214, dir: 3)
# Coordinates:
#   * time             (time) datetime64[ns] 2021-08-19T21:06:49.400000 ... 202...
#   * dir              (dir) object 'x' 'y' 'z'
# Data variables:
#     displacement     (dir, time) float64 ...
#     t_elapsed        (time) float64 ...
#     longitude        (time) float64 ...
#     latitude         (time) float64 ...
#     qc_displacement  (dir, time) int32 ...
#     qc_t_elapsed     (time) int32 ...
#     qc_longitude     (time) int32 ...
#     qc_latitude      (time) int32 ...
# Attributes:
#     title:         waves
#     description:   Example ingest of raw XYZ and GPS data taken by a Sofar Sp...
#     location_id:   buoy
#     dataset_name:  waves
#     data_level:    b1
#     datastream:    buoy.waves.b1
#     history:       Ran by mcve343 at 2022-07-13T10:15:05.192800
#     code_version:  0.0.0-post.1+1ba4b00.dirty
