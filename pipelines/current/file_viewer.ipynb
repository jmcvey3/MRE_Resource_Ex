# %%
import xarray as xr

ds = xr.open_dataset(
    "../../storage/root/data/adcp.current.a1/adcp.current.a1.20210701.133500.nc"
)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                   (time: 17383, time_b5: 17383, range: 70, dirIMU: 3, dir: 4, beam: 4, range_b5: 70, earth: 3, inst: 3, tke: 3, tau: 3)
# Coordinates:
#   * time                      (time) datetime64[ns] 2021-07-01T13:35:00.00076...
#   * time_b5                   (time_b5) datetime64[ns] 2021-07-01T13:34:59.87...
#   * range                     (range) float64 1.5 2.5 3.5 4.5 ... 68.5 69.5 70.5
#   * dirIMU                    (dirIMU) object 'E' 'N' 'U'
#   * dir                       (dir) object 'E' 'N' 'U1' 'U2'
#   * beam                      (beam) float64 1.0 2.0 3.0 4.0
#   * range_b5                  (range_b5) float64 1.5 2.5 3.5 ... 68.5 69.5 70.5
#   * earth                     (earth) object 'E' 'N' 'U'
#   * inst                      (inst) object 'X' 'Y' 'Z'
#   * tke                       (tke) object 'upup_' 'vpvp_' 'wpwp_'
#   * tau                       (tau) object 'upvp_' 'upwp_' 'vpwp_'
# Data variables: (12/56)
# ...
