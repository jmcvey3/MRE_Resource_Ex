# %%
import xarray as xr

ds = xr.open_dataset(
    "../../storage/root/data/cook_inlet.adv.b1/cook_inlet.adv.b1.20210701.134232.nc"
)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                  (time: 4340, dir: 3, beam: 3, earth: 3, inst: 3, S: 3, f: 1200, tke: 3, tau: 3)
# Coordinates:
#   * time                     (time) datetime64[ns] 2021-07-01T13:42:32.937499...
#   * dir                      (dir) object 'streamwise' 'x-stream' 'vert'
#   * beam                     (beam) float64 1.0 2.0 3.0
#   * earth                    (earth) object 'E' 'N' 'U'
#   * inst                     (inst) object 'X' 'Y' 'Z'
#   * S                        (S) object 'Sxx' 'Syy' 'Szz'
#   * f                        (f) float64 0.003333 0.006667 0.01 ... 3.997 4.0
#   * tke                      (tke) object 'upup_' 'vpvp_' 'wpwp_'
#   * tau                      (tau) object 'upvp_' 'upwp_' 'vpwp_'
# Data variables: (12/36)
#     battery_voltage          (time) float32 ...
#     speed_of_sound           (time) float32 ...
#     heading                  (time) float32 ...
#     pitch                    (time) float32 ...
# ...
